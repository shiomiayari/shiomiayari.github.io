# %% [markdown]
# <a href="https://colab.research.google.com/github/shiomiayari/shiomiayari.github.io/blob/main/Self_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytesseract pillow

# ライブラリインポート
import pytesseract
from PIL import Image
from google.colab import files
import os
import re
import cv2
import numpy as np

# 画像をアップロード
uploaded = files.upload()

# アップロードファイルの名前
filename = list(uploaded.keys())[0]

# 画像を開く
img = Image.open(filename)


# TESSDATA_PREFIX環境変数を設定
# Google Colabでは、tessdataディレクトリは/usr/share/tesseract-ocr/4.00/tessdataにあります。
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata'

# 日本語言語データをインストール
# !sudo apt install tesseract-ocr-jpn

# OCRを実行（日本語対応）
text = pytesseract.image_to_string(img, lang="jpn")

# 結果を表示
print("抽出されたテキスト:\n", text)


#ここから正規表現
import re
pattern = r"(\d{1,2}/\d{1,2})\s+(\d{1,2}:\d{2})?\s*(.+)"
matches = re.findall(pattern, text)

# 抽出結果を表示
print("\n🔹 予定一覧:")
for match in matches:
    print(f"📅 日付: {match[0]}, 🕒 時刻: {match[1] if match[1] else '終日'}, 📌 予定: {match[2]}")
# Out:
# ...
#      <input type="file" id="files-dd13da30-c0bc-47a3-9037-773b0a8b62e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd13da30-c0bc-47a3-9037-773b0a8b62e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 新しいセクション

# %% [markdown]
# # 新しいセクション
